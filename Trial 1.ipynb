# %%
# pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)

# %%
import nltk
# nltk.download()

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
paragraph = "It's official: I'm a financial ostrich. Every month, \
I run out of money and can't work out where it's all gone. When an \
unexpected bill lands on my door mat (hello, tax return!) I'm hit \
with a cold panic and, even though I have one, my savings account \
is empty."

# %%
from nltk.tokenize import sent_tokenize
print(sent_tokenize(paragraph))
# Out:
# ["It's official: I'm a financial ostrich.", "Every month, I run out of money and can't work out where it's all gone.", 'When an unexpected bill lands on my door mat (hello, tax return!)', "I'm hit with a cold panic and, even though I have one, my savings account is empty."]

# %%
from nltk.tokenize import word_tokenize, WordPunctTokenizer
print(word_tokenize(paragraph))
wpt = WordPunctTokenizer()
print(wpt.tokenize(paragraph))
# Out:
# ['It', "'s", 'official', ':', 'I', "'m", 'a', 'financial', 'ostrich', '.', 'Every', 'month', ',', 'I', 'run', 'out', 'of', 'money', 'and', 'ca', "n't", 'work', 'out', 'where', 'it', "'s", 'all', 'gone', '.', 'When', 'an', 'unexpected', 'bill', 'lands', 'on', 'my', 'door', 'mat', '(', 'hello', ',', 'tax', 'return', '!', ')', 'I', "'m", 'hit', 'with', 'a', 'cold', 'panic', 'and', ',', 'even', 'though', 'I', 'have', 'one', ',', 'my', 'savings', 'account', 'is', 'empty', '.']
# ['It', "'", 's', 'official', ':', 'I', "'", 'm', 'a', 'financial', 'ostrich', '.', 'Every', 'month', ',', 'I', 'run', 'out', 'of', 'money', 'and', 'can', "'", 't', 'work', 'out', 'where', 'it', "'", 's', 'all', 'gone', '.', 'When', 'an', 'unexpected', 'bill', 'lands', 'on', 'my', 'door', 'mat', '(', 'hello', ',', 'tax', 'return', '!)', 'I', "'", 'm', 'hit', 'with', 'a', 'cold', 'panic', 'and', ',', 'even', 'though', 'I', 'have', 'one', ',', 'my', 'savings', 'account', 'is', 'empty', '.']

# %%
from nltk import ngrams
import string
words = [word.strip(string.punctuation) for word in paragraph.split()]
bigrams = ngrams(words, 2)
print(list(bigrams))
# Out:
# [("It's", 'official'), ('official', "I'm"), ("I'm", 'a'), ('a', 'financial'), ('financial', 'ostrich'), ('ostrich', 'Every'), ('Every', 'month'), ('month', 'I'), ('I', 'run'), ('run', 'out'), ('out', 'of'), ('of', 'money'), ('money', 'and'), ('and', "can't"), ("can't", 'work'), ('work', 'out'), ('out', 'where'), ('where', "it's"), ("it's", 'all'), ('all', 'gone'), ('gone', 'When'), ('When', 'an'), ('an', 'unexpected'), ('unexpected', 'bill'), ('bill', 'lands'), ('lands', 'on'), ('on', 'my'), ('my', 'door'), ('door', 'mat'), ('mat', 'hello'), ('hello', 'tax'), ('tax', 'return'), ('return', "I'm"), ("I'm", 'hit'), ('hit', 'with'), ('with', 'a'), ('a', 'cold'), ('cold', 'panic'), ('panic', 'and'), ('and', 'even'), ('even', 'though'), ('though', 'I'), ('I', 'have'), ('have', 'one'), ('one', 'my'), ('my', 'savings'), ('savings', 'account'), ('account', 'is'), ('is', 'empty')]

# %%
from nltk.corpus import stopwords
englishstopwords = set(stopwords.words('english'))

# %%
newwords = [word for word in words if word not in englishstopwords]
print(newwords)
# Out:
# ["It's", 'official', "I'm", 'financial', 'ostrich', 'Every', 'month', 'I', 'run', 'money', "can't", 'work', 'gone', 'When', 'unexpected', 'bill', 'lands', 'door', 'mat', 'hello', 'tax', 'return', "I'm", 'hit', 'cold', 'panic', 'even', 'though', 'I', 'one', 'savings', 'account', 'empty']

# %%
dict = {'WI' : 'Wisconsin', 'TX' : 'Texas', 'AZ' : 'Arizona', 'CA' : 'California'}
for state in dict:
    print(state, dict[state])
# Out:
# WI Wisconsin
# TX Texas
# AZ Arizona
# CA California

# %%
from nltk.corpus import stopwords
englishstopwords = set(stopwords.words('english'))
with open('/content/drive/MyDrive/Colab Notebooks/reviews.csv', 'r') as infile:
    concordance = {}
    for line in infile:
        items = line.split('|')
        verse_ref = items[0]+" "+items[1]+":"+items[2]
        verse = items[3].strip()[0:-1]
        words = [word.strip(string.punctuation).lower() for word in verse.split() if word.strip(string.punctuation).lower() not in englishstopwords]
        for word in words:
            if word in concordance:
                if verse_ref not in concordance[word]:
                    concordance[word] += [verse_ref]
            else:
                concordance[word] = [verse_ref]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d36af6fbb9f6> in <module>
#       5     for line in infile:
#       6         items = line.split('|')
# ----> 7         verse_ref = items[0]+" "+items[1]+":"+items[2]
#       8         verse = items[3].strip()[0:-1]
#       9         words = [word.strip(string.punctuation).lower() for word in verse.split() if word.strip(string.punctuation).lower() not in englishstopwords]
#
# IndexError: list index out of range
